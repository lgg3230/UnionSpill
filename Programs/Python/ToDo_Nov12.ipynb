# %% [markdown]
# #### To Do

# %% [markdown]
# - OUTLINE LORI
# - RN:  writing dataset into parquet to see if it becomes lighter and if it is easier to work with
#     - parquet reduces data from 25gb to 1.3gb. god
# - CHECKS:
#     -  Check to see if worker level has same firms as firm level dataset -> there is some discrepancy because there are firms in sep24 that were not in the worker level.
#     - Check if there are missing values in worker level income variables -> see if when we aggregate to firm level, there are many missing values in employment
#     - Check if wl income variables match firm level ones -> match and have the same missing values
#
# - DEFINITIONS:
#     -  Define new hires: independently from which year they enter
#         - we have the workers that were in the firms in 2011.
#         - any worker that is not among these in subsequent years is considered a new worker
#         - the workers that were in 2011 but remain in the firm are considered the incumbents
#         - define weights as inverse of firm employment
#         - make average of specifcic firms
